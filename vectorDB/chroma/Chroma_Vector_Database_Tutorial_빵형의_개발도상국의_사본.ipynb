# %% [markdown]
# # Chroma Vector Database Tutorial
#
# 빠른 이미지 검색을 위한 벡터 데이터베이스 튜토리얼
#
# > 유튜브 [빵형의 개발도상국](https://www.youtube.com/@bbanghyong)

# %%
# !pip install -q chromadb transformers
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.3/67.3 kB 3.4 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.4/50.4 kB 1.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 584.3/584.3 kB 21.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.4/2.4 MB 66.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 273.8/273.8 kB 23.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 93.5/93.5 kB 7.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.4/76.4 kB 7.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.9/77.9 kB 6.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 75.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.6/67.6 kB 6.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.2/13.2 MB 100.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 64.0/64.0 kB 5.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 52.5/52.5 kB 4.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 149.7/149.7 kB 13.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 110.5/110.5 kB 7.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 141.9/141.9 kB 11.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.6/50.6 kB 4.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.8/62.8 kB 5.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 5.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 341.4/341.4 kB 24.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 72.0/72.0 kB 6.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.4/3.4 MB 63.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 425.7/425.7 kB 29.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 157.3/157.3 kB 13.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.0/46.0 kB 3.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.8/86.8 kB 7.9 MB/s eta 0:00:00
#   Building wheel for pypika (pyproject.toml) ... done

# %% [markdown]
# ## Dataset
#
# Food-11 데이터셋 중 evaluation 데이터 10장씩
#
# https://www.kaggle.com/datasets/trolukovich/food11-image-dataset

# %%
# !wget -q https://github.com/kairess/toy-datasets/raw/master/Food-11.zip
# !unzip -q Food-11.zip

# %%
from PIL import Image

img = Image.open("test/Bread/0.jpg")

img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=512x512>

# %% [markdown]
# ## Image Vectorizer 모델 로드
#
# https://huggingface.co/facebook/dino-vits16

# %%
from transformers import ViTFeatureExtractor, ViTModel

feature_extractor = ViTFeatureExtractor.from_pretrained('facebook/dino-vits16')
model = ViTModel.from_pretrained('facebook/dino-vits16').to("cuda")

print("Models loaded!")
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:89: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# preprocessor_config.json:   0%|          | 0.00/244 [00:00<?, ?B/s]
# /usr/local/lib/python3.10/dist-packages/transformers/models/vit/feature_extraction_vit.py:28: FutureWarning: The class ViTFeatureExtractor is deprecated and will be removed in version 5 of Transformers. Please use ViTImageProcessor instead.
#   warnings.warn(
# config.json:   0%|          | 0.00/453 [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/86.7M [00:00<?, ?B/s]
# Some weights of ViTModel were not initialized from the model checkpoint at facebook/dino-vits16 and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Models loaded!

# %% [markdown]
# ## 임베딩

# %%
img_tensor = feature_extractor(images=img, return_tensors="pt").to("cuda")
outputs = model(**img_tensor)

embedding = outputs.pooler_output.detach().cpu().numpy().squeeze()

embedding
# Out:
# array([ 0.9375875 , -0.9847166 , -0.9798911 ,  0.6898207 ,  0.495359  ,
#        -0.46836436, -0.9804991 , -0.14989538, -0.80235034,  0.9946452 ,
#         0.9346663 , -0.91325694, -0.58324134, -0.85059553, -0.24606237,
#        -0.10659982, -0.99056625, -0.9935972 , -0.513788  , -0.99697435,
#         0.1110509 , -0.98369503, -0.3391348 ,  0.41113496,  0.9993525 ,
#        -0.9956865 , -0.994139  , -0.09229054, -0.9094082 ,  0.5954283 ,
#        -0.4072215 , -0.65549934,  0.99942297, -0.9060699 , -0.4868904 ,
#         0.31044945, -0.00329064,  0.99661577,  0.99815464,  0.88367176,
#        -0.99709034, -0.3665747 ,  0.4801625 , -0.5975697 , -0.97720087,
#        -0.21000531, -0.9283192 ,  0.60402435, -0.6782695 , -0.90425164,
#        -0.5413796 ,  0.96589106,  0.9995211 , -0.81654924, -0.93031347,
#         0.94173384, -0.94381815,  0.9766665 , -0.9857552 , -0.9928435 ,
#         0.8267616 , -0.9047551 , -0.750031  ,  0.857967  , -0.9373869 ,
#        -0.90048337,  0.7695519 ,  0.43080395,  0.9502033 , -0.99124724,
#        -0.46779212,  0.6282527 , -0.7690624 , -0.7012185 , -0.9132251 ,
#        -0.9994316 ,  0.00844363, -0.9999846 ,  0.9562992 , -0.81877655,
#        -0.71214783,  0.92664725, -0.99809337, -0.9365773 , -0.9256282 ,
#         0.5046243 ,  0.999402  , -0.3549478 , -0.9959954 , -0.99571764,
#         0.9995286 , -0.84325755, -0.02764641, -0.95690495,  0.86650705,
#        -0.9967256 ,  0.6416368 , -0.9541143 , -0.9277654 , -0.07486854,
#         0.21149896, -0.8539518 ,  0.47338915,  0.6508684 ,  0.92675894,
#        -0.9050656 , -0.9428412 , -0.9880545 ,  0.991072  ,  0.92046654,
#         0.9372088 ,  0.7005613 ,  0.5084852 , -0.20997813,  0.6861889 ,
#         0.7523955 ,  0.62588775,  0.4884486 ,  0.4147513 , -0.90206015,
#         0.8054737 , -0.01797264, -0.41722775, -0.9954853 , -0.160834  ,
#         0.681937  ,  0.19217014,  0.7337993 ,  0.656191  , -0.19026001,
#         0.89243317,  0.9964065 ,  0.8641499 , -0.25770536, -0.9839183 ,
#        -0.87869734, -0.99387205, -0.7346297 , -0.9996447 ,  0.6736141 ,
#         0.48517168, -0.79752266, -0.99991643,  0.99600786, -0.91383433,
#        -0.46495262,  0.7475921 ,  0.505869  ,  0.5535072 ,  0.25901902,
#        -0.7021668 , -0.8917285 , -0.83623314,  0.16137828, -0.44244242,
#        -0.9815102 , -0.3115394 ,  0.9953443 , -0.63227844, -0.1653647 ,
#        -0.30137432, -0.96920913,  0.09449895, -0.98958725, -0.7649635 ,
#         0.56842935, -0.9844039 ,  0.84553015, -0.02908548,  0.9947714 ,
#         0.21687664, -0.47828588, -0.59739107, -0.5846599 ,  0.9709122 ,
#         0.99891627,  0.98257643,  0.34353107,  0.9975622 ,  0.9996687 ,
#        -0.51917875, -0.59896475,  0.7545113 , -0.06489333, -0.9293567 ,
#         0.65840304, -0.825827  , -0.32768178,  0.79387563,  0.3673199 ,
#         0.6194347 ,  0.8632738 , -0.25463265, -0.98121077, -0.99969065,
#        -0.99936396, -0.5344641 ,  0.94873416, -0.5771785 , -0.9808422 ,
#         0.44434136, -0.90721023, -0.39376   ,  0.25839272, -0.99307245,
#        -0.08636358, -0.15764706, -0.42872104, -0.05714015, -0.97701293,
#         0.9791981 , -0.9954218 , -0.67007506, -0.72524667,  0.66752756,
#         0.6672869 ,  0.70943916,  0.09084761, -0.88491595, -0.509544  ,
#        -0.99328214,  0.6067675 ,  0.8111003 , -0.25614157,  0.91668826,
#         0.9926743 ,  0.33931994,  0.14512162,  0.09828623, -0.97101164,
#         0.82223195, -0.98933953,  0.46117398,  0.4641437 , -0.91992414,
#         0.9871495 , -0.99897456,  0.36078838, -0.9347214 ,  0.9968211 ,
#         0.99824023,  0.98890024,  0.43256932, -0.05240731, -0.8172065 ,
#        -0.9976751 , -0.96273106, -0.8035973 , -0.99477774,  0.9832079 ,
#         0.20823719,  0.9865661 , -0.6345061 ,  0.9612875 , -0.9656196 ,
#        -0.995475  , -0.5560552 ,  0.60558105, -0.03801123, -0.8942789 ,
#        -0.51880187, -0.4236251 ,  0.7234111 , -0.9962324 , -0.9996569 ,
#        -0.6276487 ,  0.9593612 ,  0.9997603 , -0.3172585 , -0.6030635 ,
#         0.99715763, -0.0664691 ,  0.9915264 , -0.8078188 , -0.68894374,
#         0.99767363, -0.156625  , -0.8500385 ,  0.95608026, -0.8350635 ,
#        -0.85728675, -0.9906483 ,  0.81630975,  0.6570243 ,  0.45272985,
#        -0.84059507,  0.81220174, -0.8061256 , -0.9954405 ,  0.72197783,
#        -0.9593544 ,  0.76453173,  0.47018468, -0.5831962 , -0.99805355,
#        -0.84967875,  0.21475786,  0.88124996, -0.95909923,  0.99717903,
#        -0.1345134 ,  0.9994964 , -0.97835875,  0.3992867 , -0.94771075,
#        -0.8865485 ,  0.9758129 , -0.99958175, -0.12063935,  0.29760283,
#         0.99990135, -0.7795839 ,  0.92977387,  0.9896609 , -0.657014  ,
#         0.69712317,  0.7648603 ,  0.8031759 ,  0.87206143, -0.9970735 ,
#         0.9977187 , -0.9996744 ,  0.41516808, -0.3818257 ,  0.92748725,
#        -0.9996327 , -0.9891435 ,  0.98966473, -0.3134263 ,  0.9979544 ,
#         0.97604024, -0.8192049 , -0.78752023,  0.9232007 ,  0.8831638 ,
#        -0.97020733,  0.90906304, -0.9700988 ,  0.9885446 , -0.9945202 ,
#         0.1338092 ,  0.9957988 ,  0.09773649, -0.99735606, -0.9909149 ,
#         0.6109893 ,  0.21449563,  0.5356693 , -0.92385596,  0.94875616,
#        -0.12546352,  0.98715025,  0.9918184 ,  0.6209744 ,  0.30196038,
#        -0.8872165 ,  0.998145  , -0.9042624 , -0.97530496,  0.9058413 ,
#        -0.8490863 , -0.9936965 , -0.6420429 , -0.9992845 , -0.6590477 ,
#        -0.99596286, -0.10455541,  0.46094823, -0.5815891 , -0.6996412 ,
#        -0.99352753,  0.99801195,  0.8999618 , -0.839759  , -0.9192047 ,
#        -0.8156961 , -0.8559703 , -0.6190498 ,  0.96994215,  0.15910283,
#        -0.94796383,  0.7798762 , -0.91902274,  0.67349195], dtype=float32)

# %%
embedding.shape
# Out:
# (384,)

# %% [markdown]
# ## Chroma DB 시작
#
# https://www.trychroma.com

# %%
import chromadb

client = chromadb.Client()

collection = client.create_collection("foods")

# %% [markdown]
# ## 모든 이미지 벡터화

# %%
from glob import glob

img_list = sorted(glob("test/*/*.jpg"))

len(img_list)
# Out:
# 110

# %%
from tqdm import tqdm

embeddings = []
metadatas = []
ids = []

for i, img_path in enumerate(tqdm(img_list)):
    img = Image.open(img_path)
    cls = img_path.split("/")[1]

    img_tensor = feature_extractor(images=img, return_tensors="pt").to("cuda")
    outputs = model(**img_tensor)

    embedding = outputs.pooler_output.detach().cpu().numpy().squeeze().tolist()

    embeddings.append(embedding)

    metadatas.append({
        "uri": img_path,
        "name": cls
    })

    ids.append(str(i))

print("Done!")
# Out:
# 100%|██████████| 110/110 [00:01<00:00, 64.05it/s]
# Done!

# %% [markdown]
# ## 임베딩을 데이터베이스에 저장

# %%
collection.add(
    embeddings=embeddings,
    metadatas=metadatas,
    ids=ids,
)

# %% [markdown]
# ## Test1

# %%
import requests

test_img = Image.open(requests.get("https://i.ibb.co/7Ksr5mw/yNp6qTS.png", stream=True).raw).convert("RGB")

test_img
# Out:
# <PIL.Image.Image image mode=RGB size=630x472>

# %%
test_img_tensor = feature_extractor(images=test_img, return_tensors="pt").to("cuda")
test_outputs = model(**test_img_tensor)

test_embedding = test_outputs.pooler_output.detach().cpu().numpy().squeeze().tolist()

len(test_embedding)
# Out:
# 384

# %%
query_result = collection.query(
    query_embeddings=[test_embedding],
    n_results=3,
)

query_result
# Out:
# {'ids': [['8', '2', '53']],
#  'distances': [[154.97476196289062, 240.22645568847656, 299.22039794921875]],
#  'metadatas': [[{'name': 'Bread', 'uri': 'test/Bread/8.jpg'},
#    {'name': 'Bread', 'uri': 'test/Bread/2.jpg'},
#    {'name': 'Meat', 'uri': 'test/Meat/3.jpg'}]],
#  'embeddings': None,
#  'documents': [[None, None, None]],
#  'uris': None,
#  'data': None,
#  'included': ['metadatas', 'documents', 'distances']}

# %%
import matplotlib.pyplot as plt

fig, axes = plt.subplots(1, 3, figsize=(16, 10))

for i, metadata in enumerate(query_result["metadatas"][0]):
    distance = query_result["distances"][0][i]

    axes[i].imshow(Image.open(metadata["uri"]))
    axes[i].set_title(f"{metadata['name']}: {distance:.2f}")
    axes[i].axis("off")

# %% [markdown]
# ## 테스트를 위한 함수화

# %%
def query(img_url, n_results=3):
    test_img = Image.open(requests.get(img_url, stream=True).raw).convert("RGB")

    test_img_tensor = feature_extractor(images=test_img, return_tensors="pt").to("cuda")
    test_outputs = model(**test_img_tensor)

    test_embedding = test_outputs.pooler_output.detach().cpu().numpy().squeeze().tolist()

    query_result = collection.query(
        query_embeddings=[test_embedding],
        n_results=n_results,
    )

    fig, axes = plt.subplots(1, 4, figsize=(16, 10))

    axes[0].imshow(test_img)
    axes[0].set_title("Query")
    axes[0].axis("off")

    for i, metadata in enumerate(query_result["metadatas"][0]):
        distance = query_result["distances"][0][i]

        axes[i+1].imshow(Image.open(metadata["uri"]))
        axes[i+1].set_title(f"{metadata['name']}: {distance:.2f}")
        axes[i+1].axis("off")

    return query_result

# %% [markdown]
# ## Test2

# %%
query("https://i.ibb.co/JmpXmvx/QCado9g.jpg")
# Out:
# {'ids': [['47', '86', '81']],
#  'distances': [[279.9723815917969, 299.6177062988281, 300.33367919921875]],
#  'metadatas': [[{'name': 'Fried food', 'uri': 'test/Fried food/7.jpg'},
#    {'name': 'Seafood', 'uri': 'test/Seafood/6.jpg'},
#    {'name': 'Seafood', 'uri': 'test/Seafood/1.jpg'}]],
#  'embeddings': None,
#  'documents': [[None, None, None]],
#  'uris': None,
#  'data': None,
#  'included': ['metadatas', 'documents', 'distances']}

# %%
query("https://i.ibb.co/X5dkHGF/lf5C0LI.png")
# Out:
# {'ids': [['13', '44', '92']],
#  'distances': [[228.09817504882812, 259.6802978515625, 262.82879638671875]],
#  'metadatas': [[{'name': 'Dairy product', 'uri': 'test/Dairy product/3.jpg'},
#    {'name': 'Fried food', 'uri': 'test/Fried food/4.jpg'},
#    {'name': 'Soup', 'uri': 'test/Soup/2.jpg'}]],
#  'embeddings': None,
#  'documents': [[None, None, None]],
#  'uris': None,
#  'data': None,
#  'included': ['metadatas', 'documents', 'distances']}

# %%
query("https://i.ibb.co/ZVx2Fn8/WlLv0i9.png")
# Out:
# {'ids': [['77', '83', '73']],
#  'distances': [[213.1907196044922, 228.52182006835938, 230.33937072753906]],
#  'metadatas': [[{'name': 'Rice', 'uri': 'test/Rice/7.jpg'},
#    {'name': 'Seafood', 'uri': 'test/Seafood/3.jpg'},
#    {'name': 'Rice', 'uri': 'test/Rice/3.jpg'}]],
#  'embeddings': None,
#  'documents': [[None, None, None]],
#  'uris': None,
#  'data': None,
#  'included': ['metadatas', 'documents', 'distances']}
